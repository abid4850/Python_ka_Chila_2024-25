# %% [markdown]
# # Using online data or web scraping or html data

# %%
# Import Libraries
import pandas as pd
url = ('https://en.wikipedia.org/wiki/World_population')
table = pd.read_html(url)
table[5]
len(table)
# Out:
# 31

# %%
import pandas as pd
url = ('https://en.wikipedia.org/wiki/Distribution_of_wealth')
table = pd.read_html(url)
df = table[4]
df
df.to_csv(r'D:\Data_Science data\Python_ka_Chila\datasets\Distribution_of_wealth', index=False)

# %% [markdown]
# # Reading Tabluar Data

# %%
import pandas as pd

df_tabulated = pd.read_table(r'D:\Data_Science data\Python_ka_Chila\datasets\Distribution_of_wealth', sep='\t')
df_tabulated
# Out:
#     Year Bottom 99% Top 1%
# 0   1922      63.3%  36.7%
# 1   1929      55.8%  44.2%
# 2   1933      66.7%  33.3%
# 3   1939      63.6%  36.4%
# 4   1945      70.2%  29.8%
# 5   1949      72.9%  27.1%
# 6   1953      68.8%  31.2%
# 7   1962      68.2%  31.8%
# 8   1965      65.6%  34.4%
# 9   1969      68.9%  31.1%
# 10  1972      70.9%  29.1%
# 11  1976      80.1%  19.9%
# 12  1979      79.5%  20.5%
# 13  1981      75.2%  24.8%
# 14  1983      69.1%  30.9%
# 15  1986      68.1%  31.9%
# 16  1989      64.3%  35.7%
# 17  1992      62.8%  37.2%
# 18  1995      61.5%  38.5%
# 19  1998      61.9%  38.1%
# 20  2001      66.6%  33.4%
# 21  2004      65.7%  34.3%
# 22  2007      65.4%  34.6%
# 23  2010      64.6%  35.4%

# %%
import pandas as pd

df_tabulated = pd.read_table(r"D:\Data_Science data\Python_ka_Chila\datasets\Distribution_of_wealth", sep=', ', header=0)
# Out:
# C:\Users\Hasnain\AppData\Local\Temp\ipykernel_12160\1338795391.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_tabluar = pd.read_table(r"D:\Data_Science data\Python_ka_Chila\datasets\Distribution_of_wealth", sep=', ')

# %%
# Define the some name of table

import pandas as pd

df_tabulated = pd.read_table(r"D:\Data_Science data\Python_ka_Chila\datasets\Distribution_of_wealth", sep=', ', 
                           names = ['Year', 'Top'])

df_tabulated
# Out:
# C:\Users\Hasnain\AppData\Local\Temp\ipykernel_12160\3043946842.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_tabulated = pd.read_table(r"D:\Data_Science data\Python_ka_Chila\datasets\Distribution_of_wealth", sep=', ',
#                       Year  Top
# 0   Year,Bottom 99%,Top 1%  NaN
# 1         1922,63.3%,36.7%  NaN
# 2         1929,55.8%,44.2%  NaN
# 3         1933,66.7%,33.3%  NaN
# 4         1939,63.6%,36.4%  NaN
# 5         1945,70.2%,29.8%  NaN
# 6         1949,72.9%,27.1%  NaN
# 7         1953,68.8%,31.2%  NaN
# 8         1962,68.2%,31.8%  NaN
# 9         1965,65.6%,34.4%  NaN
# 10        1969,68.9%,31.1%  NaN
# 11        1972,70.9%,29.1%  NaN
# 12        1976,80.1%,19.9%  NaN
# 13        1979,79.5%,20.5%  NaN
# 14        1981,75.2%,24.8%  NaN
# ...

# %% [markdown]
# # Read Json file

# %%
import pandas as pd

df = pd.read_json('https://en.wikipedia.org/wiki/Distribution_of_wealth/json.file')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_json('https://en.wikipedia.org/wiki/Distribution_of_wealth/json.file')
#
# File c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
# ...
