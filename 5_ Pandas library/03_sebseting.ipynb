# %% [markdown]
# # Subseting the data

# %%
# Import Libraries
import pandas as pd
df = pd.read_excel(r'D:\Data_Science data\Python_ka_Chila\dataframe\titanic.xlsx')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Subser age columns from the database
age = df['age']
age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
gender = df['sex']
gender
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
# Subset two column named  age and sex.
df_age_sex = df[['age', 'sex']]
print(type(df_age_sex))
df_age_sex
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
# Filter the rows based on age column
age_filter = df['age'] > 18
age_filter
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
adults = df [df['age'] >= 18]
non_adults = df[df['age'] < 18]

adults.to_csv(r'D:\Data_Science data\Python_ka_Chila\datasets\adults.csv')

# %%
# filter the data adults males from the df sex==male and age >=18

adults_male = df[(df['sex'] == 'male') & (df['age'] >= 18)]
adults_male
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# 13          0       3  male  39.0      1      5  31.2750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# ...

# %%
# filter the data adult female from the df sex==female  and age >= 18

adults_female = df[(df['sex'] == 'female') & (df['age'] >= 18)]
adults_female
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Subseting the other method

# %%
import pandas as pd
df = pd.read_excel(r'D:\Data_Science data\Python_ka_Chila\datasets\titanic.xlsx')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Collect the data in class 2 and 3 

class_2_3 = df[(df['parch'] ==2) | (df['parch'] ==3)]
class_2_3
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 43          1       2  female   3.0      1      2   41.5792        C  Second
# 58          1       2  female   5.0      1      2   27.7500        S  Second
# 59          0       3    male  11.0      5      2   46.9000        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 846         0       3    male   NaN      8      2   69.5500        S   Third
# 850         0       3    male   4.0      4      2   31.2750        S   Third
# 858         1       3  female  24.0      0      3   19.2583        C   Third
# 863         0       3  female   NaN      8      2   69.5500        S   Third
# 888         0       3  female   NaN      1      2   23.4500        S   Third
#
# ...

# %%
# Collect the data in class 2 and 3 
class_2_3 = df[df['parch'].isin([2, 3])]
class_2_3
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 27          0       1    male  19.0      3      2  263.0000        S   First
# 43          1       2  female   3.0      1      2   41.5792        C  Second
# 58          1       2  female   5.0      1      2   27.7500        S  Second
# 59          0       3    male  11.0      5      2   46.9000        S   Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 846         0       3    male   NaN      8      2   69.5500        S   Third
# 850         0       3    male   4.0      4      2   31.2750        S   Third
# 858         1       3  female  24.0      0      3   19.2583        C   Third
# 863         0       3  female   NaN      8      2   69.5500        S   Third
# 888         0       3  female   NaN      1      2   23.4500        S   Third
#
# ...

# %% [markdown]
# # Known/unknown values in data

# %%
import pandas as pd
df = pd.read_excel(r'D:\Data_Science data\Python_ka_Chila\datasets\titanic.xlsx')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_age_known= df[df['age'].notna()] # or notnull
df_age_known
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_age_unknown = df[df['age'].isna()] # or isnull
df_age_unknown
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
