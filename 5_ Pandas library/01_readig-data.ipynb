# %% [markdown]
# # Pandas Library

# %% [markdown]
# ## Step-1 : Importing the library

# %%
import pandas as pd

# %%
# importing data from clipboard
df = pd.read_clipboard()
df
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Importing data from excel file

# %%
# Read excel file
import pandas as pd
df_excel = pd.read_excel('D:/Data_Science data/Python_ka_Chila/dataframe/titanic.xlsx')
df
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %%
# Read excel file
import pandas as pd
df_excel = pd.read_excel('D:/Data_Science data/Python_ka_Chila/dataframe/titanic.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 # Read excel file
#       2 import pandas as pd
# ----> 3 df_excel = pd.read_excel('../00_datasets/titanic.xlsx')
#
# File c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %% [markdown]
# # Import  data from csv and tsv file

# %%
# load csv data
df_csv = pd.read_csv('D:/Data_Science data/Python_ka_Chila/dataframe/companies_yield.csv')
df_csv
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...

# %%
# Import tsv data
df_tsv = pd.read_csv('D:/Data_Science data/Python_ka_Chila/dataframe/Worlds Best 50 Hotels.txt', sep='\t''decode'('utf-8'))
df_tsv
# Out:
# <>:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\Hasnain\AppData\Local\Temp\ipykernel_5276\1890760962.py:2: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df_tsv = pd.read_csv('D:/Data_Science data/Python_ka_Chila/dataframe/Worlds Best 50 Hotels.txt', sep='\t''decode'('utf-8'))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Import tsv data
# ----> 2 df_tsv = pd.read_csv('D:/Data_Science data/Python_ka_Chila/dataframe/Worlds Best 50 Hotels.txt', sep='\t''decode'('utf-8'))
#       3 df_tsv
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Dummy Dataset

# %%
# create a dataframe from a dictionary fro the people ages and names
data = {'Name': ['Muhammad', 'Ali', 'Ahmed', 'Miqdad'],
        'Age' : [28, 56, 45, 5]}
data
# Out:
# {'Name': ['Muhammad', 'Ali', 'Ahmed', 'Miqdad'], 'Age': [28, 56, 45, 5]}

# %%
df = pd.DataFrame(data)
df
# Out:
#        Name  Age
# 0  Muhammad   28
# 1       Ali   56
# 2     Ahmed   45
# 3    Miqdad    5

# %%
# create a dataframe from a dictionary fro the people ages and names
data = {'Name': ['Muhammad', 'Ali', 'Ahmed', 'Miqdad'],
        'Age' : [28, 56, 45, 5],
        'Weight' : [56, 90, 105, 20]}
data
df = pd.DataFrame(data)
df
# Out:
#        Name  Age  Weight
# 0  Muhammad   28      56
# 1       Ali   56      90
# 2     Ahmed   45     105
# 3    Miqdad    5      20

# %% [markdown]
# # Write the data

# %%
import pandas as pd
df.to_clipboard()
df
# Out:
# Empty DataFrame
# Columns: [D:\Data_Science, data\Python_ka_Chila\datasets]
# Index: []

# %%
import pandas as pd
df.to_excel('D:/Data_Science data/Python_ka_Chila/datasets')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\pandas\io\excel\_base.py:1136, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135 try:
# -> 1136     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137     if engine == "auto":
#
# File c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# ...
