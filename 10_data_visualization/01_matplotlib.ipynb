# %% [markdown]
# # Matplotlib for Data Visualization

# %%
pip install matplotlib --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
df = pd.read_excel(r"D:\Data_Science data\Python_ka_Chila\dataframe\titanic.xlsx")

# %%
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 336         0       1    male  29.0      1      0  66.6000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 190         1       2  female  32.0      0      0  13.0000        S  Second
# 81          1       3    male  29.0      0      0   9.5000        S   Third
# 131         0       3    male  20.0      0      0   7.0500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 336    man        True    C  Southampton    no  False
# 8    woman       False  NaN  Southampton   yes  False
# 190  woman       False  NaN  Southampton   yes   True
# 81     man        True  NaN  Southampton   yes   True
# 131    man        True  NaN  Southampton    no   True

# %%
# Bar Plot using matplotlib
df['survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survived'>

# %%
# create a bar plot
plt.bar(df['sex'],df['age'],color='b')
# Out:
# <BarContainer object of 891 artists>

# %%
# create a bar plot using matplotlib
plt.bar(df['who'], df['age'], color='maroon')
# Out:
# <BarContainer object of 891 artists>

# %%
# Figure Size
fig = plt.figure(figsize =(7, 4)) # width, height
# creata a bar plot using matplotlib
plt.bar(df['who'], df['age'], color='maroon')
# save the plot in png with 300 dpi resolution
plt.savefig('D:/Data_Science data/Python_ka_Chila/01_plots/bar_plot.png', dpi=300)
# save svg file
plt.savefig('D:/Data_Science data/Python_ka_Chila/01_plots/bar_plot_svg.svg', format='svg')
# show the plot
plt.show()

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
plt.scatter(df['age'], df['fare'], color='maroon')
# label plots
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Age vs Fare')
plt.show()

# %%
# creata a bar plot using matplotlib
plt.stem(df['who'], df['age'])
# Out:
# <StemContainer object of 3 artists>

# %%
plt.stackplot(df['who'], df['age'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# make data
y = [4.8, 5.5, 3.5, 4.6, 6.5, 6.6, 2.6, 3.0]

# plot
fig, ax = plt.subplots()

ax.stairs(y, linewidth=2.5)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
plt.hist(df['age'], bins=10, color='maroon')
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# # box plot
# plt.boxplot(df['pclass'], df['age'])

# %%
import seaborn as sns

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
sns.boxplot(data = df, x = 'sex', y='age')
# add labels
plt.xlabel("Gender")
plt.ylabel("Age")
plt.title("Box Plot")
plt.savefig('D:/Data_Science data/Python_ka_Chila/01_plots/box_plot_seaborn.png', dpi=300)

# %%
sns.boxenplot(data = df, x = 'sex', y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
# change the colors based on the palette
sns.set_palette("Set1")
sns.barplot(data = df, x = 'pclass', y='age', hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
# change the colors based on the palette
sns.set_palette("Set1")
sns.boxplot(data = df, x = 'pclass', y='age', hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
fig = plt.figure(figsize =(7, 4)) # width, height
# change the colors based on the palette
sns.set_palette("Set1")
sns.boxenplot(data = df, x = 'class', y='age', hue='sex', 
              order=['First', 'Second', 'Third'])
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
# Out:
# <Axes: xlabel='carat', ylabel='price'>
