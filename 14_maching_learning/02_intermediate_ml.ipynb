# %% [markdown]
# # Intermediat Machine Learning

# %% [markdown]
# # Simple Lieaner regressiion

# %% [markdown]
# <h2 style="font-family: 'poppins'; font-weight: bold;">👨‍💻Author: Abid Hussain</h2>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/abid4850)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/abidhussai512)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/abid-hussain-101846339/)
# [![Facebook](https://img.shields.io/badge/Facebook-Profile-blue?style=for-the-badge&logo=facebook)](https://www.facebook.com/profile.php?id=abid.hussainnoul)
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://twitter.com/AbidHussai76533)
# [![Instagram](https://img.shields.io/badge/Instagram-Profile-blue?style=for-the-badge&logo=instagram)](https://www.instagram.com/abidhussainnoul/)

# %%
# import libraries
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
# write the whole script in one go
# import libraries
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
# load the data
df = sns.load_dataset('tips')
# select the feature column from df
X = df[['total_bill']]
# select the target column from df
y = df['tip']
# load/call the linear regression model to
model = LinearRegression()
# fit the model means train the model
model.fit(X,y)
# lets predict the tip for an unknown total_bill
model.predict([[40]])
# Out:
# c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.12125031])

# %%
# Create a regression line plot
sns.lmplot(x='total_bill', y='tip', data=df)

# %% [markdown]
# # Multiple linear regression or Multilinear regression

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# write the whole script in one go
# import libraries
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
# load the data
df = sns.load_dataset('tips')
# select the feature column from df
X = df[['total_bill', 'size']]
# select the target column from df
y = df['tip']
# load/call the linear regression model to
model = LinearRegression()
# fit the model means train the model
model.fit(X,y)
# lets predict the tip for an unknown total_bill
model.predict([[35.574,  2]])
# Out:
# c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.35232457])

# %%
# write the whole script in one go
# import libraries
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
# load the data
df = sns.load_dataset('tips')
# encode smoker columns 
df['smoker_num']= df['smoker'].map({'Yes':1, 'No':0})
df.head()
# select the feature column from df
X = df[['total_bill', 'size', 'smoker_num']]
# select the target column from df
y = df['tip']
# load/call the linear regression model to
model = LinearRegression()
# fit the model means train the model
model.fit(X,y)
# lets predict the tip for an unknown total_bill
print(model.predict([[35.574, 3, 1]]))
print(model.predict([[35.574, 3, 0]]))
# Out:
# [4.50656323]
# [4.58999578]
# c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Classification
# ### Logistic Regression

# %%
# write the whole script in one go
# import libraries
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
# load the data
df = sns.load_dataset('tips')
# encode smoker columns 
df['smoker_num']= df['smoker'].map({'Yes':1, 'No':0})
df.head()
# select the feature column from df
X = df[['total_bill', 'size', 'tip']]
# select the target column from df
y = df['smoker']
# load/call the linear regression model to
model = LogisticRegression()
# fit the model means train the model
model.fit(X,y)
# lets predict 
model.predict([[50, 3, 5.67]])
# Out:
# c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %% [markdown]
# # Classification
# ## Logistic Regression
# ### binary classification

# %%
# write the whole script in one go
# import libraries
import pandas as pd
import seaborn as sns
# import navie bayes
from sklearn.naive_bayes import GaussianNB
# load the data
df = sns.load_dataset('tips')
# encode smoker columns 
df['smoker_num']= df['smoker'].map({'Yes':1, 'No':0})
df.head()
# select the feature column from df
X = df[['total_bill', 'size', 'tip']]
# select the target column from df
y = df['smoker']
# load/call the linear regression model to
model = GaussianNB()
# fit the model means train the model
model.fit(X,y)
# lets predict 
model.predict([[50, 3, 5.67]])
# Out:
# c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype='<U3')

# %% [markdown]
# # Decision Trees

# %%
# write the whole script in one go
# import libraries
import pandas as pd
import seaborn as sns
# import navie bayes
from sklearn.naive_bayes import GaussianNB
# Import decision tree
from sklearn.tree import DecisionTreeClassifier
# load the data
df = sns.load_dataset('tips')
# encode smoker columns 
df['smoker_num']= df['smoker'].map({'Yes':1, 'No':0})
df.head()
# select the feature column from df
X = df[['total_bill', 'size', 'tip']]
# select the target column from df
y = df['smoker']
# load/call the linear regression model to
model = DecisionTreeClassifier()
# fit the model means train the model
model.fit(X,y)
# lets predict 
model.predict([[50, 3, 5.67]])
# Out:
# c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)

# %% [markdown]
# # Decision tree Regressor

# %%
import seaborn as sns
# import navie bayes
from sklearn.naive_bayes import GaussianNB
# Import decision tree
from sklearn.tree import DecisionTreeRegressor
# load the data
df = sns.load_dataset('tips')
df.head()

X = df[['total_bill', 'size']]
y = df['tip']

model = DecisionTreeRegressor()
model.fit(X,y)

model.predict([[50.527, 2]])
# Out:
# c:\Users\Hasnain\miniconda3\envs\data_analysis\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([10.])
